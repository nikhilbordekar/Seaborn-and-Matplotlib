# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilbordekar/Seaborn-and-Matplotlib/blob/main/Seaborn_and_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SEABORN**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')
iris = sns.load_dataset('iris')
planets = sns.load_dataset('planets')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue = 'day')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue = 'day', size='size')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue = 'day', size='size', palette='YlGnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # **HISTOGRAM**

# %%
sns.histplot(tips['tip'], bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'], bins=15, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# # **DISTPLOT**

# %%
sns.distplot(tips['tip'], bins=15, kde=True)
# Out:
# <ipython-input-14-638514a5bb78>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'], bins=15, kde=True)
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # **BARPLOT**

# %%
sns.barplot(x='sex',y='tip', data=tips, palette='YlGnBu')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# # **BOXPLOT**

# %%
sns.boxplot(x='day',y='tip', data=tips, palette='YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **STRIPPLOT**

# %%
sns.stripplot(x='day', y='tip', data=tips, hue='sex', palette='YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day', y='tip', data=tips, hue='sex', palette='YlGnBu', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **JOIN PLOT: SCATTER PLOT + DISTRIBUTION PLOT**

# %%
sns.jointplot(x='tip', y='total_bill', data=tips)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='reg')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', shade=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', shade=True, cmap='YlGnBu') #cmap=color_map
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='hex',  cmap='YlGnBu') #kind=hex and no shade

# %% [markdown]
# # **PAIRPLOT**

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue='pclass')

# %% [markdown]
# # **HEATMAP**

# %%
sns.heatmap(titanic.corr(), cmap='YlGnBu')
# Out:
# <ipython-input-31-885b49ee6c4e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), cmap='YlGnBu')
# <Axes: >

# %%
sns.heatmap(titanic.corr(), cmap='YlGnBu', annot=True) #cmap= coolwarm, icefire
# Out:
# <ipython-input-32-8cf5669e37ac>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), cmap='YlGnBu', annot=True)
# <Axes: >

# %% [markdown]
# # **CLUSTERMAP**

# %%
sns.clustermap(iris.drop(['species'], axis=1))

# %% [markdown]
# ---

# %% [markdown]
# # **MATPLOTLIP**

# %% [markdown]
# ---

# %% [markdown]
# # **SCATTER PLOT**

# %%
x = np.random.random(50)
y = np.random.random(50)

plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y, marker='+')
plt.show()

# %%
plt.scatter(x,y, marker='+', c='#00f', s=150) #size and color
plt.show()

# %%
x = np.random.random(1000)
y = np.random.random(1000)
plt.scatter(x,y, marker='+', c='#00f', s=150, alpha=0.3) #transperancy
plt.show()

# %%
years = [2006 + x for x in range(16) ]
weights = [81, 83, 86, 83,88, 90, 78, 66, 89, 100, 87,77, 133, 76, 98, 79]

# %%
plt.plot(years, weights, c='r')

# %%
plt.plot(years, weights, c='r', lw=3)

# %%
plt.plot(years, weights, c='r', lw=3, linestyle='--')

# %% [markdown]
# # **BAR PLOT**

# %%
xx = ['a', 'b', 'c', 'd']
yy =[12, 32, 50, 22]

# %%
plt.bar(xx,yy, color='r') #no c --> color
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(xx,yy, color='r', width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # **HISTOGRAM **

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ages = np.random.normal(20, 1.5, 1000)

# %%
plt.hist(ages)
# Out:
# (array([  2.,  14.,  59., 162., 244., 272., 158.,  75.,  13.,   1.]),
#  array([14.64272187, 15.71163787, 16.78055388, 17.84946988, 18.91838589,
#         19.98730189, 21.0562179 , 22.1251339 , 23.19404991, 24.26296591,
#         25.33188192]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages, bins=20)
# Out:
# (array([  2.,   0.,   4.,  10.,  18.,  41.,  57., 105., 109., 135., 145.,
#         127.,  86.,  72.,  61.,  14.,   8.,   5.,   0.,   1.]),
#  array([14.64272187, 15.17717987, 15.71163787, 16.24609587, 16.78055388,
#         17.31501188, 17.84946988, 18.38392788, 18.91838589, 19.45284389,
#         19.98730189, 20.52175989, 21.0562179 , 21.5906759 , 22.1251339 ,
#         22.6595919 , 23.19404991, 23.72850791, 24.26296591, 24.79742391,
#         25.33188192]),
#  <BarContainer object of 20 artists>)
